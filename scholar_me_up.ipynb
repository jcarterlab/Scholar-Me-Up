# %% [markdown]
# # **Scholar me up**

# %% [markdown]
# This notebook shows how you can you use large language models to learn about virtually any topic, including large language models. It uses Llama 2 7B-chat (accessed from Hugging Face) and Google Colab's free GPU access to retrieve a list of relevant academic papers on a given topic before summarizing them in your prefered language style.

# %% [markdown]
# ## **Define parameters**

# %% [markdown]
# Here we define the parameters we want our model to use.

# %%
topic = 'transformers in LLMs for NLP'

language_style = 'easy to understand'

paper_type = 'most influential'

numer_of_papers = '12'

period = '2010-2024'

summary_words = '200-300'

# %% [markdown]
# ## **Load model**

# %% [markdown]
# ### **Import libraries**

# %% [markdown]
# First we import the libraries we need.

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# !pip install -q transformers einops accelerate langchain bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.7/806.7 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.5/238.5 kB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.7 MB/s eta 0:00:00

# %% [markdown]
# ### **Login to Hugging Face**

# %% [markdown]
# Then we login to Hugging Face. First you will need to get permission from Meta to use Llama 2 7B-chat and then from hugging face to use their version converted for Hugging Face Transformers. When running this cell, use your hugging face token to login then enter 'n' afterwards upon being asked to add token as git credential.

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ### **Download Llama 2 7B-chat**

# %% [markdown]
# Next we download the model and instantiate it as 'llm' before setting the temperature parameter to 0 for more truthful answers.

# %%
from langchain import HuggingFacePipeline
from transformers import AutoTokenizer
import transformers
import torch
import warnings
warnings.filterwarnings("ignore")

model = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto",
    max_length=1000,
    eos_token_id=tokenizer.eos_token_id
)

llm = HuggingFacePipeline(pipeline = pipeline, model_kwargs = {'temperature':0})
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %% [markdown]
# ## **Get papers**

# %% [markdown]
# ### **Define a prompt to get the papers**

# %% [markdown]
# Here we define our prompt format. The system information contains information on how to respond while the text conists of our chosen topic.

# %%
from langchain import PromptTemplate
import numpy as np

# calculates out how many of the papers should be after 2010 and 2023 respectively
# this is because the model sometimes tends to focus more on older papers
half_papers = int(np.floor(eval(numer_of_papers) / 2))
quarter_papers = int(np.floor(eval(numer_of_papers) / 4))

# strings to be combined to make our prompt template
start = """<s>[INST] <<SYS>>\n\n"""
line_1 = "You return " + numer_of_papers + " academic papers on a topic between " + period + " in ascending order of publication date.\n"
line_2 = str(half_papers) + " of the papers must be from 2010 onwards.\n"
line_3 = str(quarter_papers) + " of the papers must be from 2023 onwards.\n"
line_4 = "You return academic papers in 'name / author / date' format, nothing else.\n"
line_5 = "You do not describe the papers in any way, you only return the author, date and paper name.\n\n"
end = """<</SYS>>\n\n {text} [/INST]"""

template = start + line_1 + line_2 + line_3 + line_4 + line_5 + end

prompt = PromptTemplate(
    input_variables=["text"],
    template=template,
)

text = 'What are the ' + paper_type + ' academic papers on ' + topic + '?'
print(prompt.format(text=text))
# Out:
# <s>[INST] <<SYS>>
#
# You return 12 academic papers on a topic between 2010-2024 in ascending order of publication date.
# 6 of the papers must be from 2010 onwards.
# 3 of the papers must be from 2023 onwards.
# You return academic papers in 'name / author / date' format, nothing else.
# You do not describe the papers in any way, you only return the author, date and paper name.
#
# <</SYS>>
#
#  What are the most influential academic papers on transformers in LLMs for NLP? [/INST]

# %% [markdown]
# ### **Run a query to get the papers**

# %% [markdown]
# Now we run our query to get a list of papers on our topic.

# %%
from langchain.chains import LLMChain

chain = LLMChain(llm=llm, prompt=prompt)
result = chain.invoke(text)

print()
print(result['text'])
# Out:
#   Sure, here are 12 academic papers on transformers in LLMs for NLP, sorted in ascending order of publication date:
#
# 1. Vaswani et al. (2017) - "Attention is All You Need"
# 2. Parikh et al. (2016) - "A Survey on Attention Mechanisms for NLP"
# 3. Wu et al. (2016) - "Sequence to Sequence Learning with Neural Networks"
# 4. Liu et al. (2019) - "A Survey of Transformer-Based Language Models for Natural Language Processing"
# 5. Auli et al. (2018) - "On the Importance of Initialization for Transformer-Based Language Models"
# 6. Chen et al. (2020) - "Reinforcement Learning for Language Modeling: A Survey"
# 7. Zhang et al. (2020) - "Understanding the Transformer"
# 8. Li et al. (2020) - "A Survey of Transformer-Based Models for NLP"
# 9. Zhao et al. (2020) - "Transformers for Natural Language Processing: A Survey"
# 10. Wang et al. (2023) - "Transformers for Language Modeling: A Survey"
# 11. Liu et al. (2023) - "A Survey of Transformer-Based Language Models for Low-Resource Languages"
# 12. Zhang et al. (2023) - "Transformers for Multimodal Language Processing: A Survey"
#
# Note: The publication dates are based on the dates of the papers' publication on arXiv, and may not necessarily reflect their actual publication dates in academic journals.

# %% [markdown]
# ### **Store the papers in a dataframe**

# %% [markdown]
# We then extract and store our papers in a dataframe, ordering again by date in case the model didn't return the papers in the desired date order.

# %%
import pandas as pd
import re

# extracts the date with regex by looking for a pattern with any 4 digit number
def extract_date(texts):

    pattern = r'\b\d{4}\b'

    for i, text in enumerate(texts):
        match = re.search(pattern, text)
        if match:
          if text[0] == '(':
            return text[1:5]
          else:
            return text[0:4]

    return None

# creates a pandas dataframe where the papers are sorted by date
seperator = ' '
papers = []
dates = []
for paper in range(eval(numer_of_papers)):
  index = 2 + paper
  text = result['text'].split('\n')[index].split(' ')[1:]
  papers.append( seperator.join(text) )
  dates.append( extract_date(text) )


papers_df = pd.DataFrame({'paper': papers,
                          'date': dates}).sort_values('date').reset_index(drop=True)
papers_df
# Out:
#                                                 paper  date
# 0   Parikh et al. (2016) - "A Survey on Attention ...  2016
# 1   Wu et al. (2016) - "Sequence to Sequence Learn...  2016
# 2   Vaswani et al. (2017) - "Attention is All You ...  2017
# 3   Auli et al. (2018) - "On the Importance of Ini...  2018
# 4   Liu et al. (2019) - "A Survey of Transformer-B...  2019
# 5   Chen et al. (2020) - "Reinforcement Learning f...  2020
# 6   Zhang et al. (2020) - "Understanding the Trans...  2020
# 7   Li et al. (2020) - "A Survey of Transformer-Ba...  2020
# 8   Zhao et al. (2020) - "Transformers for Natural...  2020
# 9   Wang et al. (2023) - "Transformers for Languag...  2023
# 10  Liu et al. (2023) - "A Survey of Transformer-B...  2023
# 11  Zhang et al. (2023) - "Transformers for Multim...  2023

# %% [markdown]
# ## **Summarize papers**

# %% [markdown]
# ### **Define a prompt to summarize the papers**

# %% [markdown]
# Now we create another prompt template, this time asking the model to summarize a given paper.

# %%
# strings to be combined to make our prompt template
start = """<s>[INST] <<SYS>>\n\n"""
line_1 = "You summarize an academic paper in " + summary_words + " words.\n"
line_2 = "Your response only includes a summary and a detailed, bullet pointed list of what the article says which is different from other papers, nothing else.\n"
line_3 = "You use the titles '📝 Summary:', '💡 What's new:' for the headings with a newline between each.\n"
line_4 = "Do not use any other headings, only '📝 Summary:' and '💡 What's new:'.\n"
line_5 = "Use '*' for bullet points in the '💡 What's new:' section, do not write the '💡 What's new:' section as a paragraph.\n"
line_6 = "Write the summary on the same line as the '📝 Summary:' section, not on a newline."
line_7 = "Do not repeat information from the '📝 Summary:' in the '💡 What's new:' section, instead go into more detail about what the paper says.\n"
line_8 = "You do not use emojis for anything else.\n"
line_9 = "You write in " + language_style + " language.\n"
line_10 = "You begin your response with 'Paper:' followed by the name of the paper.\n\n"

end = """<</SYS>>\n\n {text} [/INST]"""

template = start + line_1 + line_2 + line_3 + line_4 + line_5 + line_6 + line_7 + line_8 + line_9 + end
0
prompt = PromptTemplate(
    input_variables=["text"],
    template=template,
)

paper = papers_df.loc[0, 'paper']
text = 'Give me a summary of the paper: "' + paper + '"'
print(prompt.format(text=text))
# Out:
# <s>[INST] <<SYS>>
#
# You summarize an academic paper in 200-300 words.
# Your response only includes a summary and a detailed, bullet pointed list of what the article says which is different from other papers, nothing else.
# You use the titles '📝 Summary:', '💡 What's new:' for the headings with a newline between each.
# Do not use any other headings, only '📝 Summary:' and '💡 What's new:'.
# Use '*' for bullet points in the '💡 What's new:' section, do not write the '💡 What's new:' section as a paragraph.
# Do not repeat information from the '📝 Summary:' in the '💡 What's new:' section, instead go into more detail about what the paper says.
# You do not use emojis for anything else.
# You write in easy to understand language.
# You begin your response with 'Paper:' followed by the name of the paper.
#
# <</SYS>>
#
#  Give me a summary of the paper: "Parikh et al. (2016) - "A Survey on Attention Mechanisms for NLP"" [/INST]

# %% [markdown]
# ### **Run a query to summarize the papers**

# %% [markdown]
# We again use our prompt to run a query, this time returning broad summaries of our papers.

# %%
results = []
for i in range(eval(numer_of_papers)):
  paper = papers_df.loc[i, 'paper']
  text = 'Give me a summary of the paper: "' + paper + '"'
  prompt.format(text=text)

  chain = LLMChain(llm=llm, prompt=prompt)
  result = chain.invoke(text)

  print()
  print()
  print()
  print(result['text'])
  results.append(result)
# Out:
#   Paper: Parikh et al. (2016) - "A Survey on Attention Mechanisms for NLP"
#
# 📝 Summary: This paper provides a comprehensive survey of attention mechanisms in natural language processing (NLP). The authors discuss the different types of attention mechanisms, including hard attention, soft attention, and multi-head attention, and their applications in various NLP tasks such as language translation, question answering, and text summarization. They also highlight the benefits of attention mechanisms, including improved performance and interpretability, and discuss some of the challenges and limitations of using attention in NLP.
#
# 💡 What's new:
#
# * The authors provide a detailed overview of the different attention mechanisms, including their mathematical formulations and the techniques used to implement them.
# * They discuss the recent advances in attention mechanisms, such as the use of multi-head attention and the development of attention-based neural machine translation.
# * The authors highlight the importance of attention mechanisms in NLP, and discuss their potential applications in areas such as dialogue systems and language generation.
# * They also discuss some of the challenges and limitations of using attention mechanisms in NLP, including the need for better interpretability and the potential for overfitting.
# * The authors provide a comprehensive list of references for further reading on attention mechanisms in NLP.
#
#
#
#   Paper: Wu et al. (2016) - "Sequence to Sequence Learning with Neural Networks"
#
# 📝 Summary: This paper proposes a new framework for sequence to sequence learning, called sequence to sequence learning with neural networks (seq2seq). The authors present a new architecture that leverages the power of neural networks to learn the mapping between input and output sequences. The proposed model is able to learn long-term dependencies and capture complex relationships between input and output sequences, making it particularly useful for tasks such as machine translation and text summarization. The authors evaluate their model on several benchmark datasets and show that it achieves state-of-the-art results.
#
# 💡 What's new:
#
# * The authors propose a new architecture called sequence to sequence learning with neural networks (seq2seq), which leverages the power of neural networks to learn the mapping between input and output sequences.
# * The proposed model is able to learn long-term dependencies and capture complex relationships between input and output sequences, making it particularly useful for tasks such as machine translation and text summarization.
# * The authors introduce a new training method called parallel corpora, which enables the training of the model on parallel corpora and improves the quality of the generated outputs.
# * The authors also propose a new evaluation metric called BLEU-4, which measures the quality of the generated outputs based on the number of matching n-grams in the reference translations.
# * The authors show that their model achieves state-of-the-art results on several benchmark datasets for machine translation and text summarization tasks.
#
#
#
#   Paper: Vaswani et al. (2017) - "Attention is All You Need"
#
# 📝 Summary:
# In this paper, Vaswani et al. propose a new neural network architecture for machine translation called the Transformer model. The Transformer model relies entirely on self-attention mechanisms, rather than traditional recurrent neural networks (RNNs) or convolutional neural networks (CNNs). The authors claim that this allows the Transformer model to be more parallelizable and efficient, leading to faster training times and improved translation quality. The paper also introduces the concept of multi-head attention, which allows the model to jointly attend to information from different representation subspaces at different positions. The authors show that the Transformer model achieves state-of-the-art results on several machine translation tasks, outperforming traditional sequence-to-sequence models.
#
# 💡 What's new:
#
# * The Transformer model relies entirely on self-attention mechanisms, rather than traditional RNNs or CNNs.
# * The authors introduce the concept of multi-head attention, which allows the model to jointly attend to information from different representation subspaces at different positions.
# * The paper shows that the Transformer model achieves state-of-the-art results on several machine translation tasks, outperforming traditional sequence-to-sequence models.
# * The Transformer model is more parallelizable and efficient than traditional models, leading to faster training times and improved translation quality.
# * The authors claim that the Transformer model is a significant improvement over traditional models, and has the potential to revolutionize the field of natural language processing.
#
#
#
#   Paper: "Auli et al. (2018) - On the Importance of Initialization for Transformer-Based Language Models"
#
# 📝 Summary: This paper investigates the impact of initialization on the performance of transformer-based language models. The authors experiment with different initialization methods and show that a well-chosen initialization can significantly improve the model's performance, especially in tasks with limited training data. They also find that the choice of initialization method can affect the model's ability to generalize to unseen data.
#
# 💡 What's new:
#
# * The authors propose a new initialization method called "Random Initiation with Adaptive Weight Normalization" (RIAN), which they show outperforms other popular initialization methods.
# * They demonstrate that RIAN helps the model learn more robust representations and improves its ability to generalize to unseen data.
# * The authors also analyze the effect of initialization on the model's ability to handle long-range dependencies and show that RIAN helps the model capture longer-range dependencies more effectively.
# * They conduct experiments on several language modeling tasks and show that RIAN consistently outperforms other initialization methods.
# * The authors also show that RIAN can be easily adapted to other transformer-based models, such as BERT and RoBERTa.
#
#
#
#   Paper: Liu et al. (2019) - "A Survey of Transformer-Based Language Models for Natural Language Processing"
#
# 📝 Summary: This paper provides a comprehensive survey of transformer-based language models for natural language processing (NLP). The authors discuss the architecture and applications of transformer-based models, including their strengths and limitations. They also highlight some of the challenges and open research directions in this area.
#
# 💡 What's new:
#
# * The paper provides a detailed overview of the transformer architecture, including its encoder-decoder structure and multi-head attention mechanism.
# * The authors discuss the various applications of transformer-based models, such as language translation, language generation, and text classification.
# * They highlight some of the challenges associated with training transformer-based models, such as the need for large amounts of training data and computational resources.
# * The authors also discuss some of the recent advances in transformer-based models, such as the use of pre-training and fine-tuning, and the development of new architectures such as the BERT and RoBERTa models.
# * The paper also provides a detailed comparison of different transformer-based models, including their performance on various NLP tasks.
# * The authors also discuss the potential applications of transformer-based models in areas such as question answering, dialogue systems, and text summarization.
#
#
#
#   Paper: Chen et al. (2020) - "Reinforcement Learning for Language Modeling: A Survey"
#
# 📝 Summary: This paper provides a comprehensive survey of reinforcement learning (RL) for language modeling. The authors discuss the challenges of training RL models for language tasks, such as the high dimensionality of language data and the need for large amounts of training data. They also highlight the potential benefits of using RL for language modeling, including improved performance and flexibility. The authors cover various RL algorithms and their applications in language modeling, including Q-learning, deep Q-networks, and policy gradient methods. They also discuss the use of RL in combination with other machine learning techniques, such as attention and transformers. Finally, the authors highlight some of the open research directions in the field of RL for language modeling.
#
# 💡 What's new:
#
# * The authors provide a detailed overview of the challenges and opportunities of using RL for language modeling.
# * They discuss the use of RL in combination with other machine learning techniques, such as attention and transformers.
# * The authors highlight several open research directions in the field, including the need for more research on the theoretical foundations of RL for language modeling and the development of more efficient and scalable RL algorithms.
# * They also discuss the potential applications of RL for language modeling in areas such as natural language processing, machine translation, and text generation.
# * The authors provide a comprehensive overview of the current state of the field and identify several areas for future research.
#
#
#
#   Paper: Zhang et al. (2020) - "Understanding the Transformer"
#
# 📝 Summary: This paper aims to provide a comprehensive understanding of the Transformer architecture, which has revolutionized the field of natural language processing (NLP) in recent years. The authors analyze the Transformer's architecture, training process, and performance, and discuss its limitations and potential avenues for improvement. They also compare the Transformer with other state-of-the-art NLP models, such as recurrent neural networks (RNNs) and convolutional neural networks (CNNs).
#
# 💡 What's new:
#
# * The authors propose a new training method called "adaptive attention" that improves the Transformer's ability to handle long-range dependencies in sequences.
# * They show that the Transformer's parallelization capabilities allow it to scale to larger datasets and tasks than previously thought possible.
# * The authors analyze the Transformer's use of "position-wise feed-forward networks" (FFNs) and show that they are responsible for the model's strong performance in certain tasks.
# * They compare the Transformer's performance to that of other state-of-the-art NLP models, such as BERT and RoBERTa, and find that it performs similarly or better in some tasks.
# * The authors discuss the Transformer's limitations, such as its reliance on large amounts of data and computational resources, and suggest potential avenues for improvement, such as using multi-resolution representations or incorporating additional modalities.
#
#
#
#   Paper: Li et al. (2020) - "A Survey of Transformer-Based Models for NLP"
#
# 📝 Summary: This paper provides a comprehensive survey of Transformer-based models for natural language processing (NLP). The authors discuss the architecture and variants of Transformer models, their applications in various NLP tasks, and recent advances in the field. They also highlight the challenges and limitations of Transformer models and suggest future research directions.
#
# 💡 What's new:
#
# * The authors provide a detailed overview of the Transformer architecture, including its encoder and decoder components, multi-head attention mechanism, and position-wise feed-forward network.
# * They discuss the variants of Transformer models, such as BERT, RoBERTa, and XLNet, which have achieved state-of-the-art results in various NLP tasks.
# * The authors highlight the applications of Transformer models in tasks such as language translation, question answering, and text classification.
# * They discuss the recent advances in Transformer models, including the use of pre-training and fine-tuning, and the development of new techniques such as multi-task learning and transfer learning.
# * The authors also discuss the challenges and limitations of Transformer models, including their computational requirements and the need for large amounts of training data.
# * They suggest future research directions, including the development of more efficient Transformer models and the integration of Transformer models with other NLP techniques.
#
#
#
#   Paper: Zhao et al. (2020) - "Transformers for Natural Language Processing: A Survey"
#
# 📝 Summary: This paper provides a comprehensive survey of Transformers, a type of neural network architecture, and their applications in natural language processing (NLP). The authors cover the origins and evolution of Transformers, their architecture, and their variants. They also discuss the advantages and limitations of Transformers and their potential applications in NLP tasks such as language translation, question answering, and text classification. The authors conclude by highlighting future research directions in Transformer-based NLP.
#
# 💡 What's new:
#
# * The authors provide a detailed overview of the Transformer architecture and its variants, including the encoder-decoder structure, multi-head attention, and position-wise feed-forward networks.
# * They discuss the use of Transformers in various NLP tasks, including language translation, question answering, and text classification, and highlight their advantages in these tasks.
# * The authors also cover the challenges and limitations of Transformers, such as their computational complexity and the need for large amounts of training data.
# * They propose several future research directions, including the development of more efficient Transformer architectures and the integration of Transformers with other NLP techniques.
# * The authors provide a detailed comparison of Transformers with other NLP techniques, such as recurrent neural networks (RNNs) and convolutional neural networks (CNNs), highlighting their strengths and weaknesses.
# * They discuss the potential applications of Transformers in areas such as language generation, text summarization, and sentiment analysis.
#
#
#
#   Sure, here is a summary of the paper "Wang et al. (2023) - "Transformers for Language Modeling: A Survey"":
#
# 📝 Summary: This paper provides a comprehensive survey of transformer-based language models, which have revolutionized the field of natural language processing in recent years. The authors discuss the architecture and training of transformer models, as well as their applications in various areas such as language translation, question answering, and text generation. They also highlight the challenges and limitations of transformer models and suggest future research directions in this area.
#
# 💡 What's new:
#
# * The authors provide a detailed overview of the transformer architecture, including the self-attention mechanism and the feed-forward network.
# * They discuss the different variants of transformer models, such as BERT, RoBERTa, and XLNet, and their performance on various language modeling tasks.
# * They analyze the effect of different hyperparameters on the performance of transformer models and provide guidelines for selecting the best hyperparameters.
# * They discuss the use of transformer models for other NLP tasks, such as sentiment analysis, named entity recognition, and dialogue generation.
# * They highlight the limitations of transformer models, such as their reliance on large amounts of training data and their difficulty in capturing long-range dependencies.
# * They suggest future research directions, such as exploring new architectures and training methods, and applying transformer models to low-resource languages.
#
#
#
#   Paper: Liu et al. (2023) - "A Survey of Transformer-Based Language Models for Low-Resource Languages"
#
# 📝 Summary: This paper provides a comprehensive survey of Transformer-based language models for low-resource languages. The authors review various Transformer-based models, including their architectures, training methods, and performance on different low-resource languages. They also discuss the challenges and limitations of these models and identify future research directions in this area.
#
# 💡 What's new:
#
# * The paper focuses on Transformer-based models, which have shown promising results in low-resource language processing tasks.
# * The authors review a wide range of Transformer-based models, including their architectures, such as the original Transformer, BERT, and RoBERTa.
# * The paper discusses the challenges of training Transformer-based models on low-resource languages, such as data scarcity and bias.
# * The authors highlight the importance of pre-training and fine-tuning Transformer-based models for low-resource languages, and provide a detailed overview of the pre-training methods used in this area.
# * The paper provides a comprehensive evaluation of the performance of Transformer-based models on various low-resource languages, including Arabic, Bengali, Hindi, and Urdu.
# * The authors identify future research directions in this area, such as developing more effective pre-training methods and improving the generalization ability of Transformer-based models to unseen languages.
#
#
#
#   Paper: Zhang et al. (2023) - "Transformers for Multimodal Language Processing: A Survey"
#
# 📝 Summary: This paper provides a comprehensive survey of transformer-based models for multimodal language processing. The authors discuss the challenges of multimodal language processing, including the lack of labeled data and the need to integrate multiple modalities. They then review various transformer-based models that have been proposed to address these challenges, including multimodal transformers, attention-based models, and hybrid models. The authors also discuss the limitations of these models and identify future research directions in this field.
#
# 💡 What's new:
#
# * The paper highlights the recent advances in transformer-based models for multimodal language processing, including the use of multimodal encoders and the integration of additional modalities such as vision and speech.
# * The authors discuss the use of attention mechanisms in multimodal transformers, which allow the model to focus on specific parts of the input data.
# * The paper also covers the use of hybrid models that combine different types of transformers, such as combination of multimodal and attention-based models.
# * The authors highlight the need for more research on the interpretability and robustness of these models, as well as their application to real-world tasks such as machine translation and question answering.
# * The paper provides a detailed analysis of the limitations of current transformer-based models for multimodal language processing, including the need for larger and more diverse datasets, and the importance of considering the temporal and spatial relationships between modalities.

# %% [markdown]
# ## **Detailed summary**

# %% [markdown]
# ### **Define a prompt to get a detailed summary**

# %% [markdown]
# We now turn our attention to a specific paper of interest by defining a prompt asking for a more detailed summary.

# %%
# strings to be combined to make our prompt template
start = """<s>[INST] <<SYS>>\n\n"""
line_1 = "You summarize an academic paper in 800-1000 words and go into significant technical detail in your response.\n"
line_2 = "You begin your response with 'Paper:' followed by the name of the paper and then, on a newline, '📝 Summary:' followed by a summary, nothing else.\n\n"

end = """<</SYS>>\n\n {text} [/INST]"""

template = start + line_1 + line_2 + end
0
prompt = PromptTemplate(
    input_variables=["text"],
    template=template,
)

paper = papers_df.loc[2, 'paper']
text = 'Give me a summary of the paper: "' + paper + '"'
print(prompt.format(text=text))
# Out:
# <s>[INST] <<SYS>>
#
# You summarize an academic paper in 800-1000 words and go into significant technical detail in your response.
# You begin your response with 'Paper:' followed by the name of the paper and then, on a newline, '📝 Summary:' followed by a summary, nothing else.
#
# <</SYS>>
#
#  Give me a summary of the paper: "Vaswani et al. (2017) - "Attention is All You Need"" [/INST]

# %% [markdown]
# ### **Run a query to get a detailed summary**

# %% [markdown]
# Finally, we run a query to get our more detailed summary on a specific paper.

# %%
chain = LLMChain(llm=llm, prompt=prompt)
result = chain.invoke(text)

print()
print(result['text'])
# Out:
#   Paper: Vaswani et al. (2017) - "Attention is All You Need"
#
# 📝 Summary:
#
# In this seminal paper, Vaswani et al. propose a new neural network architecture for sequence-to-sequence tasks, called the Transformer model. Unlike traditional recurrent neural networks (RNNs) and convolutional neural networks (CNNs), which rely on recurrence and convolution respectively, the Transformer model relies entirely on self-attention mechanisms to process input sequences. This allows the model to parallelize the computation of self-attention across all positions in a sequence, making it much faster and more scalable than previous models.
#
# The Transformer model is composed of an encoder and a decoder, each comprising multiple identical layers. Each layer in the encoder and decoder consists of a self-attention mechanism, followed by a feed-forward neural network (FFNN). The self-attention mechanism computes the weighted sum of the input tokens, where the weights are learned during training. The FFNN processes the output of the self-attention mechanism and produces the final output of the layer.
#
# The key innovation of the Transformer model is the self-attention mechanism, which allows the model to attend to different parts of the input sequence simultaneously and weigh their importance. This is in contrast to RNNs, which process the input sequence sequentially and have recurrence connections that allow them to capture long-range dependencies. The Transformer model's self-attention mechanism allows it to capture long-range dependencies more efficiently and effectively, making it particularly well-suited for tasks such as machine translation and text summarization.
#
# The authors of the paper evaluate the Transformer model on several machine translation tasks and show that it achieves state-of-the-art results. They also analyze the attention mechanisms of the model and show that it is able to capture important linguistic structures, such as syntax and semantics.
#
# The paper also introduces several techniques to improve the efficiency and scalability of the Transformer model, such as the multi-head attention mechanism, which allows the model to jointly attend to information from different representation subspaces at different positions, and the position-wise feed-forward network, which allows the model to process the output of the self-attention mechanism in parallel.
#
# Overall, the paper presents a significant breakthrough in the field of natural language processing, showing that attention mechanisms can be used to build powerful and efficient models for sequence-to-sequence tasks. The Transformer model has since become a widely-used and influential model in the field, and has been applied to a wide range of tasks beyond machine translation, including text generation and question answering.
